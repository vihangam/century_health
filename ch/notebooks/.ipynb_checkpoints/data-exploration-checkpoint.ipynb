# %%
# %load_ext kedro.ipython
# Out:
# [04/28/25 10:19:42] INFO     Registered line magic '%reload_kedro'                                   ]8;id=283085;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=665541;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=568124;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=34047;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#65\65]8;;\
#                     INFO     Resolved project path as: /Users/Vihangam_Agarwal/Downloads/code/ch.   ]8;id=907119;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=578632;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#180\180]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
#                     WARNING  /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-package ]8;id=605905;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=642850;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py#109\109]8;;\
#                              s/kedro/io/data_catalog.py:165: KedroDeprecationWarning: `DataCatalog`
#                              has been deprecated and will be replaced by `KedroDataCatalog`, in
#                              Kedro 1.0.0.Currently some `KedroDataCatalog` APIs have been retained
#                              for compatibility with `DataCatalog`, including the `datasets`
#                              property and the `get_datasets`, `_get_datasets`, `add`,` list`,
#                              `add_feed_dict`, and `shallow_copy` methods. These will be removed or
#                              replaced with updated alternatives in Kedro 1.0.0. For more details,
#                              refer to the documentation:
#                              https://docs.kedro.org/en/stable/data/index.html#kedrodatacatalog-expe
#                              rimental-feature
#                                warnings.warn(
#                     WARNING  /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-package ]8;id=598623;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=969418;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py#109\109]8;;\
#                              s/kedro/io/data_catalog.py:165: KedroDeprecationWarning: `DataCatalog`
#                              has been deprecated and will be replaced by `KedroDataCatalog`, in
#                              Kedro 1.0.0.Currently some `KedroDataCatalog` APIs have been retained
#                              for compatibility with `DataCatalog`, including the `datasets`
#                              property and the `get_datasets`, `_get_datasets`, `add`,` list`,
#                              `add_feed_dict`, and `shallow_copy` methods. These will be removed or
#                              replaced with updated alternatives in Kedro 1.0.0. For more details,
#                              refer to the documentation:
#                              https://docs.kedro.org/en/stable/data/index.html#kedrodatacatalog-expe
#                              rimental-feature
#                                warnings.warn(
#                     WARNING  /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-package ]8;id=339377;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=155535;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py#109\109]8;;\
#                              s/kedro/framework/project/__init__.py:450: UserWarning: An error
#                              occurred while importing the 'ch.pipelines.reporting' module. Nothing
#                              defined therein will be returned by 'find_pipelines'.
#
#                              Traceback (most recent call last):
#                                File
#                              "/Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packag
#                              es/kedro/framework/project/__init__.py", line 442, in find_pipelines
#                                  pipeline_module = importlib.import_module(pipeline_module_name)
#                                File
#                              "/Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/importlib/_
#                              _init__.py", line 126, in import_module
#                                  return _bootstrap._gcd_import(name, package, level)
#                                File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#                                File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#                                File "<frozen importlib._bootstrap>", line 1006, in
#                              _find_and_load_unlocked
#                                File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#                                File "<frozen importlib._bootstrap_external>", line 883, in
#                              exec_module
#                                File "<frozen importlib._bootstrap>", line 241, in
#                              _call_with_frames_removed
#                                File
#                              "/Users/Vihangam_Agarwal/Downloads/code/ch/src/ch/pipelines/reporting/
#                              __init__.py", line 3, in <module>
#                                  from .pipeline import create_pipeline # NOQA
#                                File
#                              "/Users/Vihangam_Agarwal/Downloads/code/ch/src/ch/pipelines/reporting/
#                              pipeline.py", line 3, in <module>
#                                  from .nodes import (
#                                File
#                              "/Users/Vihangam_Agarwal/Downloads/code/ch/src/ch/pipelines/reporting/
#                              nodes.py", line 1, in <module>
#                                  import matplotlib.pyplot as plt
#                              ModuleNotFoundError: No module named 'matplotlib'
#
#                                warnings.warn(
#                     WARNING  /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-package ]8;id=615301;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py\warnings.py]8;;\:]8;id=110660;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/warnings.py#109\109]8;;\
#                              s/kedro/framework/project/__init__.py:450: UserWarning: An error
#                              occurred while importing the 'ch.pipelines.data_science' module.
#                              Nothing defined therein will be returned by 'find_pipelines'.
#
#                              Traceback (most recent call last):
#                                File
#                              "/Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packag
#                              es/kedro/framework/project/__init__.py", line 442, in find_pipelines
#                                  pipeline_module = importlib.import_module(pipeline_module_name)
#                                File
#                              "/Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/importlib/_
#                              _init__.py", line 126, in import_module
#                                  return _bootstrap._gcd_import(name, package, level)
#                                File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#                                File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#                                File "<frozen importlib._bootstrap>", line 1006, in
#                              _find_and_load_unlocked
#                                File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#                                File "<frozen importlib._bootstrap_external>", line 883, in
#                              exec_module
#                                File "<frozen importlib._bootstrap>", line 241, in
#                              _call_with_frames_removed
#                                File
#                              "/Users/Vihangam_Agarwal/Downloads/code/ch/src/ch/pipelines/data_scien
#                              ce/__init__.py", line 3, in <module>
#                                  from .pipeline import create_pipeline  # NOQA
#                                File
#                              "/Users/Vihangam_Agarwal/Downloads/code/ch/src/ch/pipelines/data_scien
#                              ce/pipeline.py", line 3, in <module>
#                                  from .nodes import evaluate_model, split_data, train_model
#                                File
#                              "/Users/Vihangam_Agarwal/Downloads/code/ch/src/ch/pipelines/data_scien
#                              ce/nodes.py", line 4, in <module>
#                                  from sklearn.linear_model import LinearRegression
#                              ModuleNotFoundError: No module named 'sklearn'
#
#                                warnings.warn(
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=951723;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=512274;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro_telemetry/plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [04/28/25 10:19:43] INFO     Kedro project ch                                                       ]8;id=890809;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=420757;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#146\146]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=151929;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=47177;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#147\147]8;;\
#                              'pipelines'
# [04/28/25 10:19:46] INFO     Registered line magic 'run_viz'                                        ]8;id=69735;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=398752;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/ipython/__init__.py#153\153]8;;\

# %%
catalog
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'patients': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('/Users/Vihangam_Agarwal/Downloads/code/ch/data/01_raw/patients.csv'), "
#              "protocol='file', load_args={}, save_args={'index': False})",
#  'encounters': "kedro_datasets.pandas.parquet_dataset.ParquetDataset(filepath=PurePosixPath('/Users/Vihangam_Agarwal/Downloads/code/ch/data/01_raw/encounters.parquet'), "
#                "protocol='file', load_args={}, save_args={})",
#  'symptoms': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('/Users/Vihangam_Agarwal/Downloads/code/ch/data/01_raw/symptoms.csv'), "
#              "protocol='file', load_args={}, save_args={'index': False})",
#  'medications': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('/Users/Vihangam_Agarwal/Downloads/code/ch/data/01_raw/medications.csv'), "
#                 "protocol='file', load_args={}, save_args={'index': False})",
#  'conditions': "kedro_datasets.pandas.excel_dataset.ExcelDataset(filepath=PurePosixPath('/Users/Vihangam_Agarwal/Downloads/code/ch/data/01_raw/conditions.xlsx'), "
#                "protocol='file', load_args={'engine': 'openpyxl'}, "
#                "save_args={'index': False}, writer_args={'engine': "
#                "'openpyxl'})",
#  'parameters': "kedro.io.memory_dataset.MemoryDataset(data='<dict>')",
#  'params:model_options': "kedro.io.memory_dataset.MemoryDataset(data='<dict>')",
#  'params:model_options.test_size': "kedro.io.memory_dataset.MemoryDataset(data='<float>')",
#  'params:model_options.random_state': "kedro.io.memory_dataset.MemoryDataset(data='<int>')",
#  'params:model_options.features': "kedro.io.memory_dataset.MemoryDataset(data='<list>')"}

# %%
patients = catalog.load('patients')
encounters = catalog.load('encounters')
symptoms = catalog.load('symptoms')
medications = catalog.load('medications')
conditions = catalog.load('conditions')
# Out:
# [04/28/25 10:50:10] INFO     Loading data from patients (CSVDataset)...                         ]8;id=873070;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=260083;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#401\401]8;;\
#                     INFO     Loading data from encounters (ParquetDataset)...                   ]8;id=899271;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=460776;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#401\401]8;;\
#                     INFO     Loading data from symptoms (CSVDataset)...                         ]8;id=740381;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=193649;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#401\401]8;;\
#                     INFO     Loading data from medications (CSVDataset)...                      ]8;id=996165;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=585848;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#401\401]8;;\
#                     INFO     Loading data from conditions (ExcelDataset)...                     ]8;id=644006;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=916862;file:///Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/kedro/io/data_catalog.py#401\401]8;;\

# %%
patients['PATIENT_ID'].nunique()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10000

# %%
patients.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['PATIENT_ID', 'BIRTHDATE', 'DEATHDATE', 'SSN', 'DRIVERS', 'PASSPORT',
#        'PREFIX', 'FIRST', 'LAST', 'SUFFIX', 'MAIDEN', 'MARITAL', 'RACE',
#        'ETHNICITY', 'GENDER', 'BIRTHPLACE', 'ADDRESS', 'CITY', 'STATE',
#        'COUNTY', 'FIPS', 'ZIP', 'LAT', 'LON', 'HEALTHCARE_EXPENSES',
#        'HEALTHCARE_COVERAGE', 'INCOME'],
#       dtype='object')

# %%
encounters.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['Id', 'START', 'STOP', 'PATIENT', 'ORGANIZATION', 'PROVIDER', 'PAYER',
#        'ENCOUNTERCLASS', 'CODE', 'DESCRIPTION', 'BASE_ENCOUNTER_COST',
#        'TOTAL_CLAIM_COST', 'PAYER_COVERAGE', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='object')

# %%
symptoms.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['PATIENT', 'GENDER', 'RACE', 'ETHNICITY', 'AGE_BEGIN', 'AGE_END',
#        'PATHOLOGY', 'NUM_SYMPTOMS', 'SYMPTOMS'],
#       dtype='object')

# %%
medications.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['START', 'STOP', 'PATIENT', 'PAYER', 'ENCOUNTER', 'CODE', 'DESCRIPTION',
#        'BASE_COST', 'PAYER_COVERAGE', 'DISPENSES', 'TOTALCOST', 'REASONCODE',
#        'REASONDESCRIPTION'],
#       dtype='object')

# %%
conditions.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['START', 'STOP', 'PATIENT', 'ENCOUNTER', 'CODE', 'DESCRIPTION'], dtype='object')

# %%
patients.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              PATIENT_ID   BIRTHDATE  DEATHDATE          SSN  \
# 0  54f1059e-6250-3949-6dd0-1dda9b85d22a  2002-01-21        NaN  999-28-3364
# 1  92675303-ca5b-136a-169b-e764c5753f06  1997-04-16        NaN  999-62-9859
# 2  a0b63e97-b6fd-5fe1-8f2d-2bec915efa97  1993-02-04        NaN  999-53-6488
# 3  abc59f62-dc5a-5095-1141-80b4ee8be73b  1995-05-23        NaN  999-37-1058
# 4  28d7b56c-6056-d0a2-2991-39d6e917216c  1993-11-13        NaN  999-31-6091
#
#      DRIVERS    PASSPORT PREFIX         FIRST         LAST SUFFIX  ...  \
# 0  S99987398  X44428214X    Ms.  Fredricka415     Crist667    NaN  ...
# 1  S99999770  X75016560X    Mr.    Lorenzo669   Urrutia540    NaN  ...
# 2  S99979170  X60079936X    Mr.     Luther918  MacGyver246    NaN  ...
# 3  S99981031  X14759314X   Mrs.     Jacque955     Jones311    NaN  ...
# 4  S99958903  X63033472X   Mrs.     Angela104   Stanton715    NaN  ...
#
#          CITY  STATE           COUNTY     FIPS    ZIP       LAT         LON  \
# 0  Fort Worth  Texas   Tarrant County  48439.0  76104  0.329154  -97.399553
# 1   Arlington  Texas   Tarrant County  48439.0  76006  0.328145  -97.068885
# 2     Houston  Texas    Harris County  48339.0  77357  0.300834  -95.649706
# 3        Waco  Texas  McLennan County  48309.0  76655  0.315173  -97.292558
# 4   Levelland  Texas   Hockley County  48219.0  79336  0.337037 -102.361829
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE INCOME
# 0             9990.08                 0.0  35460
# 1            10936.80                 0.0  88407
# 2            10662.16                 0.0  41800
# 3            11455.93                 0.0  41915
# 4            12449.11                 0.0  67198
#
# [5 rows x 27 columns]

# %%
encounters.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                      Id                 START  \
# 0  6539c675-dcf2-cace-a90d-7f097d1799b3  2014-02-10T11:00:08Z
# 1  748a443c-9819-4f3a-8648-0096ace6d3fd  2014-06-04T05:19:43Z
# 2  678e03b1-21ac-fbfa-3506-17bee72a6335  2015-06-10T05:19:43Z
# 3  45987160-8815-858e-893b-6490a63e919c  2015-04-10T03:27:04Z
# 4  c56e3b19-5a51-0fc8-a82e-8bf89575ca71  2016-06-15T05:19:43Z
#
#                    STOP                               PATIENT  \
# 0  2014-02-10T11:15:08Z  54F1059E-6250-3949-6DD0-1DDA9B85D22A
# 1  2014-06-04T05:34:43Z  92675303-CA5B-136A-169B-E764C5753F06
# 2  2015-06-10T05:34:43Z  92675303-CA5B-136A-169B-E764C5753F06
# 3  2015-04-10T03:42:04Z  A0B63E97-B6FD-5FE1-8F2D-2BEC915EFA97
# 4  2016-06-15T05:34:43Z  92675303-CA5B-136A-169B-E764C5753F06
#
#                            ORGANIZATION                              PROVIDER  \
# 0  ef42ec52-a1c1-3fc5-8e52-da46f7f3970c  35088bec-f756-35d8-8140-b2b017c0eacc
# 1  02078b23-a943-3175-b5f0-8d386dd8eb56  af22b73b-d38f-3d92-8a95-bd57ac2dc3f1
# 2  02078b23-a943-3175-b5f0-8d386dd8eb56  af22b73b-d38f-3d92-8a95-bd57ac2dc3f1
# 3  44f0ad91-f33b-3fe5-ba4f-868503d593fe  a79c71d6-e0b4-3450-a0e1-ee08146aeb74
# 4  02078b23-a943-3175-b5f0-8d386dd8eb56  af22b73b-d38f-3d92-8a95-bd57ac2dc3f1
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  8fa6c185-e44e-3e34-8bd8-39be8694f4ce       wellness  410620009
# 1  b046940f-1664-3047-bca7-dfa76be352a4       wellness  410620009
# 2  b046940f-1664-3047-bca7-dfa76be352a4       wellness  162673000
# 3  734afbd6-4794-363b-9bc0-6a3981533ed5       wellness  162673000
# 4  b046940f-1664-3047-bca7-dfa76be352a4       wellness  162673000
#
#                                   DESCRIPTION  BASE_ENCOUNTER_COST  \
# 0                Well child visit (procedure)               133.36
# 1                Well child visit (procedure)               133.36
# 2  General examination of patient (procedure)               133.36
# 3  General examination of patient (procedure)               133.36
# 4  General examination of patient (procedure)               133.36
#
#    TOTAL_CLAIM_COST  PAYER_COVERAGE  REASONCODE REASONDESCRIPTION
# 0            405.36             0.0         NaN              None
# 1            269.36             0.0         NaN              None
# 2            269.36             0.0         NaN              None
# 3            677.36             0.0         NaN              None
# 4            269.36             0.0         NaN              None

# %%
encounters[encounters['PATIENT']=="92675303-ca5b-136a-169b-e764c5753f06"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [Id, START, STOP, PATIENT, ORGANIZATION, PROVIDER, PAYER, ENCOUNTERCLASS, CODE, DESCRIPTION, BASE_ENCOUNTER_COST, TOTAL_CLAIM_COST, PAYER_COVERAGE, REASONCODE, REASONDESCRIPTION]
# Index: []

# %%
patients[patients['PATIENT_ID']=="92675303-CA5B-136A-169B-E764C5753F06"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [PATIENT_ID, BIRTHDATE, DEATHDATE, SSN, DRIVERS, PASSPORT, PREFIX, FIRST, LAST, SUFFIX, MAIDEN, MARITAL, RACE, ETHNICITY, GENDER, BIRTHPLACE, ADDRESS, CITY, STATE, COUNTY, FIPS, ZIP, LAT, LON, HEALTHCARE_EXPENSES, HEALTHCARE_COVERAGE, INCOME]
# Index: []
#
# [0 rows x 27 columns]

# %%
patients[patients['PATIENT_ID'].isin(encounters['PATIENT'])]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [PATIENT_ID, BIRTHDATE, DEATHDATE, SSN, DRIVERS, PASSPORT, PREFIX, FIRST, LAST, SUFFIX, MAIDEN, MARITAL, RACE, ETHNICITY, GENDER, BIRTHPLACE, ADDRESS, CITY, STATE, COUNTY, FIPS, ZIP, LAT, LON, HEALTHCARE_EXPENSES, HEALTHCARE_COVERAGE, INCOME]
# Index: []
#
# [0 rows x 27 columns]

# %%
encounters[encounters['PATIENT'].isin(patients['PATIENT_ID'])]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [Id, START, STOP, PATIENT, ORGANIZATION, PROVIDER, PAYER, ENCOUNTERCLASS, CODE, DESCRIPTION, BASE_ENCOUNTER_COST, TOTAL_CLAIM_COST, PAYER_COVERAGE, REASONCODE, REASONDESCRIPTION]
# Index: []

# %%
patients[patients['PATIENT_ID'].isin(conditions['PATIENT'])]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Empty DataFrame
# Columns: [PATIENT_ID, BIRTHDATE, DEATHDATE, SSN, DRIVERS, PASSPORT, PREFIX, FIRST, LAST, SUFFIX, MAIDEN, MARITAL, RACE, ETHNICITY, GENDER, BIRTHPLACE, ADDRESS, CITY, STATE, COUNTY, FIPS, ZIP, LAT, LON, HEALTHCARE_EXPENSES, HEALTHCARE_COVERAGE, INCOME]
# Index: []
#
# [0 rows x 27 columns]

# %%
patients[patients['PATIENT_ID'].isin(medications['PATIENT'])]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 PATIENT_ID   BIRTHDATE  DEATHDATE  \
# 4     28d7b56c-6056-d0a2-2991-39d6e917216c  1993-11-13        NaN
# 9     239ae86a-96db-6211-9042-d3f2850aabb8  1969-05-26        NaN
# 11    6c434506-fb4b-3e3f-c19d-553dec3b6c17  1959-08-02        NaN
# 12    6872def5-772f-427c-3053-de6e1c71ce0a  1959-01-07        NaN
# 15    d92132ce-06ac-3ab4-217f-97257a290b22  1965-09-14        NaN
# ...                                    ...         ...        ...
# 9978  ae46ea17-eb0a-6159-14dd-9d9fa7956be4  1961-02-20        NaN
# 9980  1919f8be-c547-6682-cb20-84bcae0259b3  1955-09-13        NaN
# 9987  8b509749-aaab-30b8-9a67-e8620eec19f0  1976-06-07        NaN
# 9996  34f0ea6d-5e68-4572-4f02-70abf4de4076  1963-12-17        NaN
# 9999  8d116ace-7fb6-7d5f-b86b-94547cbd796d  1968-03-07        NaN
#
#               SSN    DRIVERS    PASSPORT PREFIX        FIRST             LAST  \
# 4     999-31-6091  S99958903  X63033472X   Mrs.    Angela104       Stanton715
# 9     999-74-7366  S99980857  X88473183X    Mr.   Darrell400        Muller251
# 11    999-44-3322  S99985936   X7405738X   Mrs.   Claudia969        Gracia333
# 12    999-96-6821  S99953992  X30944505X    Mr.    Alfred550          West559
# 15    999-65-7810  S99931471  X65294064X   Mrs.  Dannette613       Stroman228
# ...           ...        ...         ...    ...          ...              ...
# 9978  999-33-2006  S99986497  X17725663X    Ms.    Jettie913       Hilpert278
# 9980  999-91-3934  S99991137  X75766822X   Mrs.     Mayte822      Pichardo350
# 9987  999-75-6593  S99974522  X73182518X    Mr.     Jesús825        Riojas420
# 9996  999-15-2894  S99980164  X53365291X    Mr.        Bo157     Jaskolski867
# 9999  999-22-1771  S99910062  X65201727X    Mr.     Andrew29  Pfannerstill264
#
#      SUFFIX  ...          CITY  STATE             COUNTY     FIPS    ZIP  \
# 4       NaN  ...     Levelland  Texas     Hockley County  48219.0  79336
# 9       NaN  ...   San Antonio  Texas       Bexar County  48029.0  78260
# 11      NaN  ...        Dallas  Texas      Dallas County  48113.0  75052
# 12      NaN  ...  Flower Mound  Texas      Denton County  48121.0  75077
# 15      NaN  ...          Post  Texas       Garza County  48169.0  79356
# ...     ...  ...           ...    ...                ...      ...    ...
# 9978    NaN  ...   Brownsville  Texas     Cameron County  48061.0  78583
# 9980    NaN  ...       Houston  Texas      Harris County  48201.0  77346
# 9987    NaN  ...     Grapevine  Texas     Tarrant County  48121.0  75022
# 9996    NaN  ...   Cinco Ranch  Texas   Fort Bend County      NaN      0
# 9999    NaN  ...        Austin  Texas  Williamson County  48453.0  78736
#
#            LAT         LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 4     0.337037 -102.361829            12449.11                0.00   67198
# 9     0.295071  -98.720826            14497.75             3714.72    3928
# 11    0.328933  -96.991787            12819.78             3442.72    5779
# 12    0.330731  -97.106502            21161.93                0.00  363895
# 15    0.333183 -101.294374            19010.57                0.00   70833
# ...        ...         ...                 ...                 ...     ...
# 9978  0.259860  -97.356251            15531.76                0.00   43273
# 9980  0.299623  -95.420820            16353.72             4967.14   19187
# 9987  0.329460  -97.181018            12820.53             2016.20   27681
# 9996  0.297249  -95.772813            18605.74                0.00  183359
# 9999  0.302975  -97.763314            19529.91                0.00   36223
#
# [2784 rows x 27 columns]

# %%
patients[patients['PATIENT_ID'].isin(symptoms['PATIENT'])]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 PATIENT_ID   BIRTHDATE  DEATHDATE  \
# 4     28d7b56c-6056-d0a2-2991-39d6e917216c  1993-11-13        NaN
# 11    6c434506-fb4b-3e3f-c19d-553dec3b6c17  1959-08-02        NaN
# 17    44a8ca45-6c6e-38bb-fac0-ddbf7a7ee3a4  1971-08-26        NaN
# 42    780ec78c-22a0-fcdb-17c6-ae9b2fcace9c  1976-12-12        NaN
# 63    cf5956bb-34f2-841b-2505-57b99991c377  1990-01-24        NaN
# ...                                    ...         ...        ...
# 9907  9e72a2cb-726b-d466-4d16-170f8f446fc6  1992-09-26        NaN
# 9942  110d2862-432d-5b0d-c83c-0096fc84fc64  1982-10-14        NaN
# 9944  b0cf454b-47bb-4654-d06e-ea07d4c868b4  1979-01-25        NaN
# 9978  ae46ea17-eb0a-6159-14dd-9d9fa7956be4  1961-02-20        NaN
# 9987  8b509749-aaab-30b8-9a67-e8620eec19f0  1976-06-07        NaN
#
#               SSN    DRIVERS    PASSPORT PREFIX       FIRST        LAST  \
# 4     999-31-6091  S99958903  X63033472X   Mrs.   Angela104  Stanton715
# 11    999-44-3322  S99985936   X7405738X   Mrs.  Claudia969   Gracia333
# 17    999-51-4389  S99916438  X49044901X    Mr.   Rudolf736    Rohan584
# 42    999-23-8384  S99975300  X39564403X   Mrs.  Juliane376   Barton704
# 63    999-36-9799  S99929280  X85067957X   Mrs.   Dagmar148     King743
# ...           ...        ...         ...    ...         ...         ...
# 9907  999-16-3430  S99948714  X63486126X   Mrs.   Jonell764   Kirlin939
# 9942  999-19-7236  S99938105  X16294187X   Mrs.      Rona40    Robel940
# 9944  999-56-3957  S99940923  X13298960X   Mrs.   Cassey386    Nolan344
# 9978  999-33-2006  S99986497  X17725663X    Ms.   Jettie913  Hilpert278
# 9987  999-75-6593  S99974522  X73182518X    Mr.    Jesús825   Riojas420
#
#      SUFFIX  ...         CITY  STATE             COUNTY     FIPS    ZIP  \
# 4       NaN  ...    Levelland  Texas     Hockley County  48219.0  79336
# 11      NaN  ...       Dallas  Texas      Dallas County  48113.0  75052
# 17      NaN  ...      Pantego  Texas     Tarrant County  48439.0  76013
# 42      NaN  ...    Wolfforth  Texas     Lubbock County  48303.0  79382
# 63      NaN  ...   Cedar Park  Texas  Williamson County  48453.0  78750
# ...     ...  ...          ...    ...                ...      ...    ...
# 9907    NaN  ...       Austin  Texas      Travis County  48453.0  78746
# 9942    NaN  ...      Lubbock  Texas     Lubbock County  48303.0  79404
# 9944    NaN  ...      Houston  Texas      Harris County  48201.0  77017
# 9978    NaN  ...  Brownsville  Texas     Cameron County  48061.0  78583
# 9987    NaN  ...    Grapevine  Texas     Tarrant County  48121.0  75022
#
#            LAT         LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 4     0.337037 -102.361829            12449.11                0.00   67198
# 11    0.328933  -96.991787            12819.78             3442.72    5779
# 17    0.326687  -97.106182            12993.45                0.00   47847
# 42    0.334746 -101.982682            13483.21                0.00  116672
# 63    0.303922  -97.814552            11630.68                0.00   47402
# ...        ...         ...                 ...                 ...     ...
# 9907  0.301803  -97.842313            11807.08                0.00   86069
# 9942  0.335326 -101.927881            15168.54                0.00   51546
# 9944  0.297903  -95.623320             7565.11             4666.72   18227
# 9978  0.259860  -97.356251            15531.76                0.00   43273
# 9987  0.329460  -97.181018            12820.53             2016.20   27681
#
# [948 rows x 27 columns]

# %%
is_unique = patients[['PATIENT_ID']].drop_duplicates().shape[0] == patients.shape[0]
print(is_unique)
# Out:
# True

# %%
is_unique = encounters[['Id']].drop_duplicates().shape[0] == encounters.shape[0]
print(is_unique)
# Out:
# True

# %%
is_unique = conditions[['CODE']].drop_duplicates().shape[0] == conditions.shape[0]
print(is_unique)
# Out:
# False

# %%
is_unique = conditions[['CODE','ENCOUNTER']].drop_duplicates().shape[0] == conditions.shape[0]
print(is_unique)
# Out:
# True

# %%
is_unique = conditions[['CODE','PATIENT']].drop_duplicates().shape[0] == conditions.shape[0]
print(is_unique)
# Out:
# True

# %%
is_unique = conditions[['ENCOUNTER','PATIENT','CODE']].drop_duplicates().shape[0] == conditions.shape[0]
print(is_unique)
# Out:
# True

# %%
conditions.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         START  STOP                               PATIENT  \
# 0  2020-04-21   NaN  28D7B56C-6056-D0A2-2991-39D6E917216C
# 1  2001-11-07   NaN  239AE86A-96DB-6211-9042-D3F2850AABB8
# 2  2001-11-07   NaN  239AE86A-96DB-6211-9042-D3F2850AABB8
# 3  2017-11-05   NaN  6C434506-FB4B-3E3F-C19D-553DEC3B6C17
# 4  1989-09-15   NaN  6872DEF5-772F-427C-3053-DE6E1C71CE0A
#
#                               ENCOUNTER       CODE          DESCRIPTION
# 0  402dfaeb-1888-f562-4651-f75203eb1e28  200936003  Lupus erythematosus
# 1  10d39d6f-7d98-8d03-8866-0a7cd363890b  200936003  Lupus erythematosus
# 2  10d39d6f-7d98-8d03-8866-0a7cd363890b  271737000    Anemia (disorder)
# 3  add4fa37-cabe-a5aa-f9da-8117464bad04  200936003  Lupus erythematosus
# 4  d8a684cb-6ce1-5909-59e7-3422469d18d0  200936003  Lupus erythematosus

# %%
is_unique = symptoms[['PATIENT']].drop_duplicates().shape[0] == symptoms.shape[0]
print(is_unique)
# Out:
# False

# %%
symptoms.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 PATIENT  GENDER   RACE    ETHNICITY  \
# 0  28d7b56c-6056-d0a2-2991-39d6e917216c     NaN  white     hispanic
# 1  6c434506-fb4b-3e3f-c19d-553dec3b6c17     NaN  black     hispanic
# 2  44a8ca45-6c6e-38bb-fac0-ddbf7a7ee3a4     NaN  white  nonhispanic
# 3  780ec78c-22a0-fcdb-17c6-ae9b2fcace9c     NaN  white     hispanic
# 4  cf5956bb-34f2-841b-2505-57b99991c377     NaN  white  nonhispanic
#
#    AGE_BEGIN  AGE_END            PATHOLOGY  NUM_SYMPTOMS  \
# 0         26      NaN  Lupus erythematosus             4
# 1         58      NaN  Lupus erythematosus             4
# 2         50      NaN  Lupus erythematosus             4
# 3         39      NaN  Lupus erythematosus             4
# 4         29      NaN  Lupus erythematosus             3
#
#                                     SYMPTOMS
# 0   Rash:34;Joint Pain:39;Fatigue:9;Fever:12
# 1  Rash:19;Joint Pain:44;Fatigue:48;Fever:15
# 2    Rash:2;Joint Pain:32;Fatigue:12;Fever:6
# 3  Rash:30;Joint Pain:30;Fatigue:41;Fever:19
# 4   Rash:28;Joint Pain:26;Fatigue:33;Fever:5

# %%
is_unique = symptoms[['PATIENT','PATHOLOGY']].drop_duplicates().shape[0] == symptoms.shape[0]
print(is_unique)
# Out:
# True

# %%
is_unique = medications[['PATIENT','ENCOUNTER','CODE']].drop_duplicates().shape[0] == medications.shape[0]
print(is_unique)
# Out:
# True

# %%
patients.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              PATIENT_ID   BIRTHDATE  DEATHDATE          SSN  \
# 0  54f1059e-6250-3949-6dd0-1dda9b85d22a  2002-01-21        NaN  999-28-3364
# 1  92675303-ca5b-136a-169b-e764c5753f06  1997-04-16        NaN  999-62-9859
# 2  a0b63e97-b6fd-5fe1-8f2d-2bec915efa97  1993-02-04        NaN  999-53-6488
# 3  abc59f62-dc5a-5095-1141-80b4ee8be73b  1995-05-23        NaN  999-37-1058
# 4  28d7b56c-6056-d0a2-2991-39d6e917216c  1993-11-13        NaN  999-31-6091
#
#      DRIVERS    PASSPORT PREFIX         FIRST         LAST SUFFIX  ...  \
# 0  S99987398  X44428214X    Ms.  Fredricka415     Crist667    NaN  ...
# 1  S99999770  X75016560X    Mr.    Lorenzo669   Urrutia540    NaN  ...
# 2  S99979170  X60079936X    Mr.     Luther918  MacGyver246    NaN  ...
# 3  S99981031  X14759314X   Mrs.     Jacque955     Jones311    NaN  ...
# 4  S99958903  X63033472X   Mrs.     Angela104   Stanton715    NaN  ...
#
#          CITY  STATE           COUNTY     FIPS    ZIP       LAT         LON  \
# 0  Fort Worth  Texas   Tarrant County  48439.0  76104  0.329154  -97.399553
# 1   Arlington  Texas   Tarrant County  48439.0  76006  0.328145  -97.068885
# 2     Houston  Texas    Harris County  48339.0  77357  0.300834  -95.649706
# 3        Waco  Texas  McLennan County  48309.0  76655  0.315173  -97.292558
# 4   Levelland  Texas   Hockley County  48219.0  79336  0.337037 -102.361829
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE INCOME
# 0             9990.08                 0.0  35460
# 1            10936.80                 0.0  88407
# 2            10662.16                 0.0  41800
# 3            11455.93                 0.0  41915
# 4            12449.11                 0.0  67198
#
# [5 rows x 27 columns]
# 25/04/28 14:06:11 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:06:11 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:06:21 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:06:21 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:06:31 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:06:31 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# ...
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:07:21 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:07:21 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more

# %%
import pandas as pd
pd.to_datetime(patients['BIRTHDATE'])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 import pandas as pd                                                                          │
# │ ❱ 2 pd.to_datetime(patients['BIRTHDATE'])                                                        │
# │   3                                                                                              │
# │                                                                                                  │
# │ /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/pandas/core/tools/dateti │
# │ mes.py:1067 in to_datetime                                                                       │
# │                                                                                                  │
# │   1064 │   │   if not cache_array.empty:                                                         │
# │   1065 │   │   │   result = arg.map(cache_array)                                                 │
# │   1066 │   │   else:                                                                             │
# │ ❱ 1067 │   │   │   values = convert_listlike(arg._values, format)                                │
# │   1068 │   │   │   result = arg._constructor(values, index=arg.index, name=arg.name)             │
# │   1069 │   elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):                             │
# │   1070 │   │   result = _assemble_from_unit_mappings(arg, errors, utc)                           │
# │                                                                                                  │
# │ /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/pandas/core/tools/dateti │
# │ mes.py:433 in _convert_listlike_datetimes                                                        │
# │                                                                                                  │
# │    430 │                                                                                         │
# │    431 │   # `format` could be inferred, or user didn't ask for mixed-format parsing.            │
# │    432 │   if format is not None and format != "mixed":                                          │
# │ ❱  433 │   │   return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)       │
# │    434 │                                                                                         │
# │    435 │   result, tz_parsed = objects_to_datetime64(                                            │
# │    436 │   │   arg,                                                                              │
# │                                                                                                  │
# │ /Users/Vihangam_Agarwal/.conda/envs/ch_env/lib/python3.10/site-packages/pandas/core/tools/dateti │
# │ mes.py:467 in _array_strptime_with_fallback                                                      │
# │                                                                                                  │
# │    464 │   """                                                                                   │
# │    465 │   Call array_strptime, with fallback behavior depending on 'errors'.                    │
# │    466 │   """                                                                                   │
# │ ❱  467 │   result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)        │
# │    468 │   if tz_out is not None:                                                                │
# │    469 │   │   unit = np.datetime_data(result.dtype)[0]                                          │
# │    470 │   │   dtype = DatetimeTZDtype(tz=tz_out, unit=unit)                                     │
# │                                                                                                  │
# │ in pandas._libs.tslibs.strptime.array_strptime:501                                               │
# │                                                                                                  │
# │ in pandas._libs.tslibs.strptime.array_strptime:451                                               │
# │                                                                                                  │
# │ in pandas._libs.tslibs.strptime._parse_with_format:583                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: time data "9999-99-99" doesn't match format "%Y-%m-%d", at position 50. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to
# use `dayfirst` alongside this.
# 25/04/28 14:10:41 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:10:41 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:10:51 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:10:51 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:01 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:01 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more

# %%
patients[patients['BIRTHDATE']=="9999-99-99"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 PATIENT_ID   BIRTHDATE  DEATHDATE  \
# 50    de064367-b981-212e-7640-35b1c6fc7b50  9999-99-99        NaN
# 159   2b283224-3047-1486-e2fa-f7044e5ab67e  9999-99-99        NaN
# 373   8f48bcc9-693d-5a6e-2ed2-1bc7f7251579  9999-99-99        NaN
# 456   57aee294-c157-5296-b6fc-433a6fed7b76  9999-99-99        NaN
# 461   90492245-5b35-6b44-88ea-7fa05b1a4700  9999-99-99        NaN
# ...                                    ...         ...        ...
# 9833  3fb230bd-cef6-0baf-6030-f27e586b5811  9999-99-99        NaN
# 9940  a181d3db-2f7d-f256-eaa2-d5ea3baf8889  9999-99-99        NaN
# 9979  038fdcf0-587c-7d72-3595-cd9d1dc6890e  9999-99-99        NaN
# 9986  8235954b-c04b-4431-fe70-8a6f2adfa21e  9999-99-99        NaN
# 9993  f1b0c8ab-7ebf-f084-31ba-ecdc71132fae  9999-99-99        NaN
#
#               SSN    DRIVERS    PASSPORT PREFIX       FIRST             LAST  \
# 50    999-21-7544        NaN         NaN    NaN   Tobias236         Walsh511
# 159   999-18-2672  S99922401   X1516703X    Mr.   Lemuel304    Swaniawski813
# 373   999-59-9732  S99962947  X54863921X   Mrs.   Alecia465        Willms744
# 456   999-38-9931  S99994906  X25580084X    Mr.     Luis923        Zapata667
# 461   999-36-8563  S99939721  X80500576X   Mrs.    Kerri159  Pfannerstill264
# ...           ...        ...         ...    ...         ...              ...
# 9833  999-79-4520  S99945746   X6680031X   Mrs.     Devin82       Krajcik437
# 9940  999-85-7238  S99995367   X5659012X    Mr.     Hong136        Senger904
# 9979  999-13-6736  S99956801  X85389603X    Mr.      Max124          Metz686
# 9986  999-24-8303        NaN         NaN    NaN  Teofila990           Bode78
# 9993  999-65-6220  S99950559  X37823910X    Ms.   Desire394        Marvin195
#
#      SUFFIX  ...          CITY  STATE             COUNTY     FIPS    ZIP  \
# 50      NaN  ...        Conroe  Texas  Montgomery County  48339.0  77303
# 159     NaN  ...   San Antonio  Texas       Bexar County  48029.0  78226
# 373     NaN  ...        Dallas  Texas      Dallas County  48113.0  75251
# 456     NaN  ...      Angleton  Texas    Brazoria County  48039.0  77515
# 461     NaN  ...   San Antonio  Texas       Bexar County  48029.0  78244
# ...     ...  ...           ...    ...                ...      ...    ...
# 9833    NaN  ...    Atascocita  Texas      Harris County  48201.0  77346
# 9940    NaN  ...         Selma  Texas       Bexar County  48187.0  78154
# 9979    NaN  ...    Atascocita  Texas      Harris County  48201.0  77346
# 9986    NaN  ...  Travis Ranch  Texas     Kaufman County      NaN      0
# 9993    NaN  ...       Mission  Texas     Hidalgo County  48215.0  78572
#
#            LAT        LON HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE  INCOME
# 50    0.301998 -95.446873             9822.82                0.00   60928
# 159   0.296262 -98.534420            18457.39                0.00  107301
# 373   0.328455 -96.905203            10932.82             3442.72   17776
# 456   0.292012 -95.484179            11857.70                0.00   76934
# 461   0.294292 -98.526957            11295.06                0.00  142588
# ...        ...        ...                 ...                 ...     ...
# 9833  0.300311 -95.177934            17996.56              916.98   85087
# 9940  0.295845 -98.281916            14936.49                0.00   69329
# 9979  0.300034 -95.134047            10787.60                0.00  156630
# 9986  0.327574 -96.433721             9553.46                0.00  124365
# 9993  0.262448 -98.367345             4365.62             7070.72    2654
#
# [150 rows x 27 columns]
# 25/04/28 14:11:11 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:11 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:21 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:21 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:31 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:31 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.dispatchOrAddCallback(Promise.scala:316)
# 	at scala.concurrent.impl.Promise$DefaultPromise.onComplete(Promise.scala:307)
# 	at scala.concurrent.impl.Promise.transformWith(Promise.scala:40)
# 	at scala.concurrent.impl.Promise.transformWith$(Promise.scala:38)
# 	at scala.concurrent.impl.Promise$DefaultPromise.transformWith(Promise.scala:187)
# 	at scala.concurrent.Future.flatMap(Future.scala:306)
# 	at scala.concurrent.Future.flatMap$(Future.scala:306)
# 	at scala.concurrent.impl.Promise$DefaultPromise.flatMap(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.asyncSetupEndpointRefByURI(NettyRpcEnv.scala:150)
# 	... 17 more
# 25/04/28 14:11:41 WARN Executor: Issue communicating with driver in heartbeater
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:101)
# 	at org.apache.spark.rpc.RpcEndpointRef.askSync(RpcEndpointRef.scala:85)
# 	at org.apache.spark.storage.BlockManagerMaster.registerBlockManager(BlockManagerMaster.scala:80)
# 	at org.apache.spark.storage.BlockManager.reregister(BlockManager.scala:642)
# 	at org.apache.spark.executor.Executor.reportHeartBeat(Executor.scala:1223)
# 	at org.apache.spark.executor.Executor.$anonfun$heartbeater$1(Executor.scala:295)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:1928)
# 	at org.apache.spark.Heartbeater$$anon$1.run(Heartbeater.scala:46)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.runAndReset(FutureTask.java:305)
# 	at java.base/java.util.concurrent.ScheduledThreadPoolExecutor$ScheduledFutureTask.run(ScheduledThreadPoolExecutor.java:305)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	... 3 more
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:11:41 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.driverEndpoint$lzycompute(BlockManagerMasterEndpoint.scala:124)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$driverEndpoint(BlockManagerMasterEndpoint.scala:123)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$lzycompute$1(BlockManagerMasterEndpoint.scala:688)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.isExecutorAlive$1(BlockManagerMasterEndpoint.scala:687)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint.org$apache$spark$storage$BlockManagerMasterEndpoint$$register(BlockManagerMasterEndpoint.scala:725)
# 	at org.apache.spark.storage.BlockManagerMasterEndpoint$$anonfun$receiveAndReply$1.applyOrElse(BlockManagerMasterEndpoint.scala:133)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:103)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: org.apache.spark.rpc.RpcEndpointNotFoundException: Cannot find endpoint: spark://CoarseGrainedScheduler@172.30.240.105:53450
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1(NettyRpcEnv.scala:148)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$asyncSetupEndpointRefByURI$1$adapted(NettyRpcEnv.scala:144)
# 	at scala.concurrent.Future.$anonfun$flatMap$1(Future.scala:307)
# 	at scala.concurrent.impl.Promise.$anonfun$transformWith$1(Promise.scala:41)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at scala.concurrent.BatchingExecutor$Batch.processBatch$1(BatchingExecutor.scala:67)
# 	at scala.concurrent.BatchingExecutor$Batch.$anonfun$run$1(BatchingExecutor.scala:82)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at scala.concurrent.BlockContext$.withBlockContext(BlockContext.scala:85)
# 	at scala.concurrent.BatchingExecutor$Batch.run(BatchingExecutor.scala:59)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.unbatchedExecute(Future.scala:875)
# 	at scala.concurrent.BatchingExecutor.execute(BatchingExecutor.scala:110)
# 	at scala.concurrent.BatchingExecutor.execute$(BatchingExecutor.scala:107)
# 	at scala.concurrent.Future$InternalCallbackExecutor$.execute(Future.scala:873)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.trySuccess(Promise.scala:94)
# 	at scala.concurrent.Promise.trySuccess$(Promise.scala:94)
# 	at scala.concurrent.impl.Promise$DefaultPromise.trySuccess(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.onSuccess$1(NettyRpcEnv.scala:225)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5(NettyRpcEnv.scala:239)
# 	at org.apache.spark.rpc.netty.NettyRpcEnv.$anonfun$askAbortable$5$adapted(NettyRpcEnv.scala:238)
# 	at scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# 	at org.apache.spark.util.ThreadUtils$$anon$1.execute(ThreadUtils.scala:99)
# 	at scala.concurrent.impl.ExecutionContextImpl$$anon$4.execute(ExecutionContextImpl.scala:138)
# 	at scala.concurrent.impl.CallbackRunnable.executeWithValue(Promise.scala:72)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.$anonfun$tryComplete$1$adapted(Promise.scala:288)
# 	at scala.concurrent.impl.Promise$DefaultPromise.tryComplete(Promise.scala:288)
# 	at scala.concurrent.Promise.complete(Promise.scala:53)
# 	at scala.concurrent.Promise.complete$(Promise.scala:52)
# 	at scala.concurrent.impl.Promise$DefaultPromise.complete(Promise.scala:187)
# 	at scala.concurrent.Promise.success(Promise.scala:86)
# 	at scala.concurrent.Promise.success$(Promise.scala:86)
# 	at scala.concurrent.impl.Promise$DefaultPromise.success(Promise.scala:187)
# 	at org.apache.spark.rpc.netty.LocalNettyRpcCallContext.send(NettyRpcCallContext.scala:50)
# 	at org.apache.spark.rpc.netty.NettyRpcCallContext.reply(NettyRpcCallContext.scala:32)
# 	at org.apache.spark.rpc.netty.RpcEndpointVerifier$$anonfun$receiveAndReply$1.applyOrElse(RpcEndpointVerifier.scala:31)
# 	... 8 more
# 25/04/28 14:11:41 ERROR Executor: Exit as unable to send heartbeats to driver more than 60 times
